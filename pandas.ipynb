# %% [markdown]
# <a href="https://colab.research.google.com/github/yosshi18/PANDA/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importar la libreria
import pandas as pd

# %%
#ayuda de pandas
help(pd.Series.iloc)
# Out:
# Help on property:
#
#     Purely integer-location based indexing for selection by position.
#
#     .. deprecated:: 2.2.0
#
#        Returning a tuple from a callable is deprecated.
#
#     ``.iloc[]`` is primarily integer position based (from ``0`` to
#     ``length-1`` of the axis), but may also be used with a boolean
#     array.
#
#     Allowed inputs are:
#
#     - An integer, e.g. ``5``.
#     - A list or array of integers, e.g. ``[4, 3, 0]``.
#     - A slice object with ints, e.g. ``1:7``.
#     - A boolean array.
#     - A ``callable`` function with one argument (the calling Series or
#       DataFrame) and that returns valid output for indexing (one of the above).
#       This is useful in method chains, when you don't have a reference to the
#       calling object, but would like to base your selection on
#       some value.
#     - A tuple of row and column indexes. The tuple elements consist of one of the
#       above inputs, e.g. ``(0, 1)``.
#
# ...

# %% [markdown]
# TOMA DE DATOS

# %%
diccionario=[{'a':2,'b':4,'c':9},{'a':16,'b':89,'c':78}]
df=pd.DataFrame(diccionario)
df
# Out:
#     a   b   c
# 0   2   4   9
# 1  16  89  78

# %% [markdown]
# SERIES

# %%
#crear una serie
serie=pd.Series([2,3,6,5,4,7,8], index= ['a','b','c','d','e','f','g'])
serie
# Out:
# a    2
# b    3
# c    6
# d    5
# e    4
# f    7
# g    8
# dtype: int64

# %%
#borrar series
serie2=serie.drop(['a','b'])
serie2
# Out:
# c    6
# d    5
# e    4
# f    7
# g    8
# dtype: int64

# %%
#seleccionar filas o serie
serie[['b','d']]
# Out:
# b    3
# d    5
# dtype: int64

# %%
#asisgnacion
serie['b']=100
serie
# Out:
# a      2
# b    100
# c      6
# d      5
# e      4
# f      7
# g      8
# dtype: int64

# %%
#operadores
serie4=(serie+serie2)
serie4
# Out:
# a     NaN
# b     NaN
# c    12.0
# d    10.0
# e     8.0
# f    14.0
# g    16.0
# dtype: float64

# %%
serie4=(serie*serie2)
serie4
# Out:
# a     NaN
# b     NaN
# c    36.0
# d    25.0
# e    16.0
# f    49.0
# g    64.0
# dtype: float64

# %%
#dicision
serie4=(serie/serie2)
serie4
# Out:
# a    NaN
# b    NaN
# c    1.0
# d    1.0
# e    1.0
# f    1.0
# g    1.0
# dtype: float64

# %% [markdown]
# DATAFRAME

# %%
datos={'Alumnos':['M Mar', 'lucia', 'Juan', 'Eva'], 'Nota':[20,10,15,8]}
df=pd.DataFrame(datos,columns=['Alumnos','Nota'])
df
# Out:
#   Alumnos  Nota
# 0   M Mar    20
# 1   lucia    10
# 2    Juan    15
# 3     Eva     8

# %% [markdown]
# entrada salida y escritura

# %%
df_to_csv=df.to_csv('/content/misDatos.csv',index=False,header=True)

# %%
mis_datos=pd.read_csv('/content/misDatos.csv',header=None,nrows=2)
mis_datos.columns=['Alumno','Nota']
mis_datos
# Out:
#     Alumno  Nota
# 0  Alumnos  Nota
# 1    M Mar    20
